# %% [markdown]
# <a href="https://colab.research.google.com/github/denverkim/SNUI7/blob/main/7_snui_day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 모델 로딩
import keras
from keras.models import load_model

model=load_model('/content/cats_and_dogs.keras')

# %%
# 테스트 이미지 열기
from PIL import Image

dog = Image.open('/content/chihuahua.jpg')
dog
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1058x1411>

# %%
# 이미지 사이즈 변경 (150, 150)
dog = dog.resize((150,150))
dog
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
# 넘파이 배열로 변경
import numpy as np

dog = np.array(dog)
dog
# Out:
# array([[[228, 228, 230],
#         [228, 228, 230],
#         [226, 226, 227],
#         ...,
#         [ 37,  35,  31],
#         [ 34,  32,  29],
#         [ 36,  32,  29]],
#
#        [[226, 226, 227],
#         [223, 223, 224],
#         [219, 220, 220],
#         ...,
#         [ 38,  35,  31],
#         [ 37,  33,  30],
#         [ 33,  31,  27]],
#
#        [[217, 217, 216],
#         [213, 212, 213],
#         [207, 206, 205],
#         ...,
#         [ 40,  36,  33],
#         [ 37,  33,  30],
#         [ 34,  32,  28]],
#
#        ...,
#
#        [[138, 129, 121],
#         [139, 130, 121],
#         [150, 142, 132],
#         ...,
#         [146, 160, 175],
#         [153, 166, 182],
#         [158, 171, 187]],
#
#        [[141, 132, 123],
#         [152, 143, 134],
#         [157, 149, 138],
#         ...,
#         [149, 162, 177],
#         [157, 171, 187],
#         [161, 174, 191]],
#
#        [[146, 137, 128],
#         [160, 151, 142],
#         [153, 145, 134],
# ...

# %%
# 이미지 reshape
dog = dog.reshape(1,150,150,3)
dog
# Out:
# array([[[[228, 228, 230],
#          [228, 228, 230],
#          [226, 226, 227],
#          ...,
#          [ 37,  35,  31],
#          [ 34,  32,  29],
#          [ 36,  32,  29]],
#
#         [[226, 226, 227],
#          [223, 223, 224],
#          [219, 220, 220],
#          ...,
#          [ 38,  35,  31],
#          [ 37,  33,  30],
#          [ 33,  31,  27]],
#
#         [[217, 217, 216],
#          [213, 212, 213],
#          [207, 206, 205],
#          ...,
#          [ 40,  36,  33],
#          [ 37,  33,  30],
#          [ 34,  32,  28]],
#
#         ...,
#
#         [[138, 129, 121],
#          [139, 130, 121],
#          [150, 142, 132],
#          ...,
#          [146, 160, 175],
#          [153, 166, 182],
#          [158, 171, 187]],
#
#         [[141, 132, 123],
#          [152, 143, 134],
#          [157, 149, 138],
#          ...,
#          [149, 162, 177],
#          [157, 171, 187],
#          [161, 174, 191]],
#
#         [[146, 137, 128],
# ...

# %%
# 테스트 이미지 예측
model.predict(dog)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# array([[1.]], dtype=float32)

# %%
# 글자로 변경
if model.predict(dog) >= .5:
    print('dog')
else:
    print('cat')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# dog

# %% [markdown]
# # 허깅페이스 사용하는 방법

# %%
# 테스트 이미지 열기
from PIL import Image
import requests

url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
image = Image.open(requests.get(url, stream=True).raw)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
# 허깅페이스 토큰 설정
from google.colab import userdata
hf_token_key = userdata.get('hftoken')

import os
os.environ['HF_TOKEN'] = hf_token_key

# %%
# 전처리기, 분류기 로딩
from transformers import ViTImageProcessor, ViTForImageClassification

processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224')
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224')
# Out:
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  346MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
# 입력 데이터 준비
inputs = processor(images=image, return_tensors="pt")
outputs = model(**inputs)

# %%
# 예측값
logits = outputs.logits
logits
# Out:
# tensor([[-2.7452e-01,  8.2146e-01, -8.6473e-02,  4.1477e-01,  5.6142e-01,
#           1.8409e-01, -5.7770e-01, -4.6060e-01, -5.3367e-01,  2.3936e-01,
#          -3.1960e-01, -5.9779e-01, -6.6347e-01, -4.9709e-01, -6.2408e-01,
#          -1.3500e+00, -9.9511e-02, -6.2133e-01,  1.1018e-01, -1.1050e+00,
#          -2.0867e-01,  3.1634e-01, -9.3123e-01, -3.0772e-01, -1.0128e+00,
#          -1.8732e-01,  5.8824e-01, -3.6184e-01, -7.4702e-01,  7.4152e-01,
#          -3.6639e-01, -2.7560e-01,  3.6597e-01, -1.1216e+00, -9.0778e-02,
#          -1.1332e+00,  1.5390e-01, -1.0403e+00,  1.0136e+00, -1.0393e+00,
#          -2.4203e+00,  5.1170e-01,  4.9378e-01, -7.4068e-01, -1.5811e+00,
#          -3.2497e-01, -2.0446e+00, -4.8239e-01, -6.3622e-01, -1.1364e+00,
#          -1.0896e+00, -4.5760e-02, -6.4020e-01, -2.3927e-01,  1.3238e-01,
#          -1.2653e+00, -4.7159e-01, -4.3720e-01, -9.5625e-01, -5.9625e-01,
#           5.0901e-01, -8.5032e-02,  2.6896e-01, -8.8226e-04, -5.3269e-01,
# ...

# %%
# 가장 확률이 높은 값 출력
predicted_class_idx = logits.argmax(-1).item()
predicted_class_idx
# Out:
# 285

# %%
# 예측값을 라벨값으로 변경
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# Predicted class: Egyptian cat
